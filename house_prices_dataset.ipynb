# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashriekke60-lgtm/Python-Basic-Projects/blob/main/house_prices_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-49d01e94-460c-446c-891f-43f80708c648" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49d01e94-460c-446c-891f-43f80708c648">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = '/content/house_prices_dataset.csv'
df = pd.read_csv(filepath)
df
# Out:
#           city     locality  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0       Mumbai      Andheri         3          2         2128      3321
# 1        Delhi  Vasant Kunj         5          3          353      3018
# 2         Pune  Viman Nagar         1          4         4692      5764
# 3      Chennai        Adyar         4          3         1632      7747
# 4       Mumbai       Bandra         1          3         3586      5829
# ..         ...          ...       ...        ...          ...       ...
# 995     Mumbai       Bandra         2          4         3639      3692
# 996  Bengaluru  Indiranagar         4          2         2447      3517
# 997    Chennai   Anna Nagar         1          2         2419      7339
# 998       Pune      Kothrud         2          3         1813      9392
# 999  Bengaluru   HSR Layout         3          3          703      2565
#
#      floors  year_built  year_renovated      property_type  parking facing  \
# ...

# %%
print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#       city     locality  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   Mumbai      Andheri         3          2         2128      3321       3
# 1    Delhi  Vasant Kunj         5          3          353      3018       3
# 2     Pune  Viman Nagar         1          4         4692      5764       2
# 3  Chennai        Adyar         4          3         1632      7747       2
# 4   Mumbai       Bandra         1          3         3586      5829       1
#
#    year_built  year_renovated      property_type  parking facing lift  \
# 0        1963            1973  Independent House        0  North  Yes
# 1        2004            2013              Villa        1  South   No
# 2        1960            1996              Villa        1  North  Yes
# 3        1976            2017              Villa        0  South  Yes
# 4        1977            2012              Villa        1   West   No
#
# ...

# %%
print("Last 5 Rows:")
print(df.tail())
# Out:
# Last 5 Rows:
#           city     locality  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 995     Mumbai       Bandra         2          4         3639      3692
# 996  Bengaluru  Indiranagar         4          2         2447      3517
# 997    Chennai   Anna Nagar         1          2         2419      7339
# 998       Pune      Kothrud         2          3         1813      9392
# 999  Bengaluru   HSR Layout         3          3          703      2565
#
#      floors  year_built  year_renovated      property_type  parking facing  \
# 995       2        1973            1987      Builder Floor        2   East
# 996       3        1962            2015              Villa        0  South
# 997       3        2023               0      Builder Floor        3   West
# 998       2        1998            2005  Independent House        1   West
# 999       1        1967            2012          Apartment        0   West
#
#     lift      furnishing  nearby_schools  nearby_hospitals  \
# ...

# %%
print("Shape:")
print(df.shape)
# Out:
# Shape:
# (1000, 20)

# %%
print("Columns:")
print(df.columns)
# Out:
# Columns:
# Index(['city', 'locality', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'year_built', 'year_renovated', 'property_type', 'parking',
#        'facing', 'lift', 'furnishing', 'nearby_schools', 'nearby_hospitals',
#        'society', 'balcony', 'garden', 'price'],
#       dtype='object')

# %%
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   city              1000 non-null   object
#  1   locality          1000 non-null   object
#  2   bedrooms          1000 non-null   int64
#  3   bathrooms         1000 non-null   int64
#  4   sqft_living       1000 non-null   int64
#  5   sqft_lot          1000 non-null   int64
#  6   floors            1000 non-null   int64
#  7   year_built        1000 non-null   int64
#  8   year_renovated    1000 non-null   int64
#  9   property_type     1000 non-null   object
#  10  parking           1000 non-null   int64
#  11  facing            1000 non-null   object
#  12  lift              1000 non-null   object
#  13  furnishing        1000 non-null   object
#  14  nearby_schools    1000 non-null   int64
#  15  nearby_hospitals  1000 non-null   int64
# ...

# %%
print("Summary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#           bedrooms    bathrooms  sqft_living     sqft_lot       floors  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.991000     2.497000  2642.602000  6382.279000     1.965000
# std       1.385944     1.106895  1364.939466  2258.807423     0.808968
# min       1.000000     1.000000   300.000000   580.000000     1.000000
# 25%       2.000000     2.000000  1431.250000  4721.250000     1.000000
# 50%       3.000000     2.500000  2644.500000  6449.500000     2.000000
# 75%       4.000000     3.000000  3852.500000  8299.000000     3.000000
# max       5.000000     4.000000  4999.000000  9998.000000     3.000000
#
#         year_built  year_renovated      parking  nearby_schools  \
# count  1000.000000     1000.000000  1000.000000     1000.000000
# mean   1986.611000     1899.470000     1.469000        4.918000
# std      21.939485      449.885359     1.131512        3.219883
# ...

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# city                object
# locality            object
# bedrooms             int64
# bathrooms            int64
# sqft_living          int64
# sqft_lot             int64
# floors               int64
# year_built           int64
# year_renovated       int64
# property_type       object
# parking              int64
# facing              object
# lift                object
# furnishing          object
# nearby_schools       int64
# nearby_hospitals     int64
# society             object
# balcony              int64
# garden              object
# price                int64
# dtype: object

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# city                0
# locality            0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# year_built          0
# year_renovated      0
# property_type       0
# parking             0
# facing              0
# lift                0
# furnishing          0
# nearby_schools      0
# nearby_hospitals    0
# society             0
# balcony             0
# garden              0
# price               0
# dtype: int64

# %%
print("Unique Values:")
print(df.nunique())
# Out:
# Unique Values:
# city                  5
# locality             25
# bedrooms              5
# bathrooms             4
# sqft_living         897
# sqft_lot            944
# floors                3
# year_built           76
# year_renovated       74
# property_type         4
# parking               4
# facing                4
# lift                  2
# furnishing            3
# nearby_schools       11
# nearby_hospitals      6
# society             100
# balcony               4
# garden                2
# price               988
# dtype: int64

# %%
print("6 Random Rows:")
print(df.sample(6))
# Out:
# 6 Random Rows:
#           city     locality  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 474       Pune    Hinjewadi         4          2         4156      6492
# 512      Delhi        Saket         4          4          512      4617
# 570      Delhi        Saket         2          2         3397      9758
# 31   Bengaluru  Koramangala         1          1          554      4655
# 612       Pune        Baner         5          3         3220      8336
# 212     Mumbai         Juhu         3          1         4599      9372
#
#      floors  year_built  year_renovated  property_type  parking facing lift  \
# 474       1        1971            2023  Builder Floor        0  South   No
# 512       1        1984            1990  Builder Floor        3  North   No
# 570       2        1956            1990  Builder Floor        1  North  Yes
# 31        1        1952            1970      Apartment        1   West  Yes
# ...

# %%
print("Value count of ‘city’ Column")
print(df["city"].value_counts())
# Out:
# Value count of ‘city’ Column
# city
# Pune         207
# Chennai      205
# Mumbai       201
# Bengaluru    197
# Delhi        190
# Name: count, dtype: int64
