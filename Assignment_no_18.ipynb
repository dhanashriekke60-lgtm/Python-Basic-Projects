# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashriekke60-lgtm/Python-Basic-Projects/blob/main/Assignment_no_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b699edf-5199-4a55-8ff0-d103835de4df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b699edf-5199-4a55-8ff0-d103835de4df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Q1. Data Loading & Initial Analysis
# i)Load the Ford Car Dataset
filepath = '/content/ford_car_dataset.csv'
df = pd.read_csv(filepath)
df
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
# ii) Display the first 10 rows
print("Display First 10 Rows:")
df.head(10)
# Out:
# Display First 10 Rows:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
# iii)Display the last 5 rows
print("Display the last 5 rows:")
df.tail(5)
# Out:
# Display the last 5 rows:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961  B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962  B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963  Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965  Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
# iv)Display Shape
print("Shape of Dataset:")
df.shape
# Out:
# Shape of Dataset:
# (17966, 9)

# %%
# v)Display Data Type
print("Data Type of Dataset:")
df.dtypes
# Out:
# Data Type of Dataset:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
# Observation:
# 1. Dataset loaded successfully.
# 2. Shape shows the total number of rows and columns.
# 3. Data contains both numeric and categorical columns.

# %%
# Q2. Missing & Duplicate Values
# Check Missing values
print("missing Values:")
print(df.isnull().sum())

# Duplicate Rows
print("\nDuplicate rows:")
print(df.duplicated().sum())

# Remove Duplicates
df = df.drop_duplicates()

print("\nShape After Removing Duplicates")
print(df.shape)

# Observation:
# Missing values are checked.
# Duplicate rows are removed.
# Out:
# missing Values:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
#
# Duplicate rows:
# 154
#
# Shape After Removing Duplicates
# (17812, 9)

# %%
# Q3: Statistical Summary
# Generate the statistical summary of all numeric columns
print("Statistical Summary of numeric column:")
df.describe()
# Out:
# Statistical Summary of numeric column:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
# Key numeric columns
columns = ['price', 'mileage', 'year']

for col in columns:
    print("Statistics for", col)
    print("Minimum :", df[col].min())
    print("Maximum :", df[col].max())
    print("Mean    :", df[col].mean())
    print("Median  :", df[col].median())
    print()
# Out:
# Statistics for price
# Minimum : 495
# Maximum : 54995
# Mean    : 12269.556310352571
# Median  : 11288.0
#
# Statistics for mileage
# Minimum : 1
# Maximum : 177644
# Mean    : 23381.146362003143
# Median  : 18277.0
#
# Statistics for year
# Minimum : 1996
# Maximum : 2060
# Mean    : 2016.8623961374353
# Median  : 2017.0

# %%
# Q4: Histogram of Numeric Features
import pandas as pd
import matplotlib.pyplot as plt

# numeric columns
columns = ['price', 'mileage', 'year', 'engineSize', 'mpg']

# Plot histograms
plt.figure(figsize=(15, 10))

for i, col in enumerate(columns, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# Observations:
# 1)Most values are concentrated in a specific range.
# 2)Some outliers are present.
# 3)Data is not uniformly distributed.
# 4)Recent model years are more frequent.
# 5)Histograms help understand the data distribution.

# %%
# Q5: Count Plots of Categorical Features
import matplotlib.pyplot as plt
import seaborn as sns

# Select categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
print("Categorical columns:")
print(categorical_cols)
# Out:
# Categorical columns:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
colors = ["blue", "red", "black"]

for i, col in enumerate(categorical_cols):
    plt.figure(figsize=(6,5))

    sns.countplot(data=df, x=col, color=colors[i])

    plt.title(f"Count Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# Observations:
# 1. The tallest bar represents the most common category.
# 2. Fuel type shows the most preferred fuel.
# 3. Transmission shows whether Manual or Automatic cars are more common.
# 4. Model plot shows the most common car models.

# %%
# Q6. Correlation Heatmap
import matplotlib.pyplot as plt
import seaborn as sns

# only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr_matrix = numeric_df.corr()

# Plot Heatmap
plt.figure(figsize=(10,6))

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap", fontsize=14)
plt.tight_layout()
plt.show()

# Observations:
# 1. Dark red indicates a strong positive correlation.
# 2. Dark blue indicates a strong negative correlation.
# 3. Values close to 1 or -1 show a strong relationship.
# 4. Values close to 0 indicate a weak or no relationship.
# 5. Check the 'price' row/column to identify which features are most correlated with price.

# %%
# Q7: Feature Identification
import matplotlib.pyplot as plt
import seaborn as sns

X = df.drop('price', axis=1)
y = df['price']

print("Independent Features (X):")
print(X.columns)

print("\nDependent Feature (y):")
print(y.name)
# Out:
# Independent Features (X):
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Dependent Feature (y):
# price

# %%
# Q8: Encoding Categorical Variables
import matplotlib.pyplot as plt
import seaborn as sns

categorical_cols = df.select_dtypes(include=['object']).columns
print("Categorical Columns:")
print(categorical_cols)

# Before Encoding (Show first 5 rows of 2 columns)
print("\nBefore Encoding:")
print(df[['fuelType', 'transmission']].head())

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=categorical_cols)

# After Encoding (Show first 5 rows)
print("\nAfter Encoding:")
print(df_encoded.head())

# Observations:
# 1. One-Hot Encoding converts categorical values into numeric (0 and 1).
# 2. Each category becomes a separate column.
# 3. This allows machine learning algorithms to work with categorical data.
# Out:
# Categorical Columns:
# Index(['model', 'transmission', 'fuelType'], dtype='object')
#
# Before Encoding:
#   fuelType transmission
# 0   Petrol    Automatic
# 1   Petrol       Manual
# 2   Petrol       Manual
# 3   Petrol       Manual
# 4   Petrol    Automatic
#
# After Encoding:
#    year  price  mileage  tax   mpg  engineSize  model_B-MAX  model_C-MAX  \
# 0  2017  12000    15944  150  57.7         1.0        False        False
# 1  2018  14000     9083  150  57.7         1.0        False        False
# 2  2017  13000    12456  150  57.7         1.0        False        False
# 3  2019  17500    10460  145  40.3         1.5        False        False
# 4  2019  16500     1482  145  48.7         1.0        False        False
#
#    model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0           False       False  ...                 False
# 1           False       False  ...                 False
# 2           False       False  ...                 False
# ...

# %%
# Q9: Feature Scaling
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# Independent Features
X = df_encoded.drop('price', axis=1)

# Apply StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert scaled data into DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Display first 5 rows
print("First 5 Rows of Scaled Data:")
print(X_scaled.head())

# Observations
# 1. StandardScaler scales all independent features.
# 2. The scaled features have a mean close to 0.
# 3. The scaled features have a standard deviation close to 1.
# 4. Scaling improves the performance of many machine learning algorithms.
# Out:
# First 5 Rows of Scaled Data:
#        year   mileage       tax       mpg  engineSize  model_B-MAX  \
# 0  0.067059 -0.382994  0.591380 -0.020597   -0.810561    -0.141575
# 1  0.554393 -0.736317  0.591380 -0.020597   -0.810561    -0.141575
# 2  0.067059 -0.562616  0.591380 -0.020597   -0.810561    -0.141575
# 3  1.041726 -0.665405  0.510777 -1.737858    0.345325    -0.141575
# 4  1.041726 -1.127749  0.510777 -0.908836   -0.810561    -0.141575
#
#    model_C-MAX  model_EcoSport  model_Edge  model_Escort  ...  \
# 0    -0.177155       -0.259896   -0.107903     -0.007493  ...
# 1    -0.177155       -0.259896   -0.107903     -0.007493  ...
# 2    -0.177155       -0.259896   -0.107903     -0.007493  ...
# 3    -0.177155       -0.259896   -0.107903     -0.007493  ...
# 4    -0.177155       -0.259896   -0.107903     -0.007493  ...
#
#    model_Tourneo Custom  model_Transit Tourneo  transmission_Automatic  \
# 0             -0.062361              -0.007493                3.486416
# ...

# %%
# Q10: Mini Project - Complete Preprocessing Pipeline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 1)Load and clean the data (handle missing & duplicate values).
# Load Dataset
df = pd.read_csv('/content/ford_car_dataset.csv')

# Handle Missing Values
print("Missing Values:")
print(df.isnull().sum())

# Remove Missing Values
df = df.dropna()

# Check Duplicate Values
print("\nDuplicate Values:", df.duplicated().sum())

# Remove Duplicate Values
df = df.drop_duplicates()

# 2)Perform EDA (histograms + count plots + heatmap).

# Histograms
numeric_cols = df.select_dtypes(include=['int64','float64']).columns

plt.figure(figsize=(15,8))
for i, col in enumerate(numeric_cols,1):
    plt.subplot(2,3,i)
    plt.hist(df[col], bins=20, color='blue', edgecolor='black')
    plt.title(col)

plt.tight_layout()
plt.show()

# Count Plots
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col, hue=col, legend=False, palette="Set2")
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=90)
    plt.show()

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(), annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title("Correlation Heatmap")
plt.show()

# 3)Identify input and output features.
X = df.drop('price', axis=1)
y = df['price']

print("\nInput Features:")
print(X.columns)

print("\nOutput Feature:")
print(y.name)

# 4)Encode categorical variables
X = pd.get_dummies(X, drop_first=True)

print("\nEncoded Data:")
print(X.head())

# 5)Scale the numeric features.
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print("\nFirst 5 Rows of Scaled Data:")
print(X_scaled.head())
# Out:
# Missing Values:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
#
# Duplicate Values: 154
# Input Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Output Feature:
# price
#
# Encoded Data:
#    year  mileage  tax   mpg  engineSize  model_C-MAX  model_EcoSport  \
# 0  2017    15944  150  57.7         1.0        False           False
# 1  2018     9083  150  57.7         1.0        False           False
# 2  2017    12456  150  57.7         1.0        False           False
# 3  2019    10460  145  40.3         1.5        False           False
# 4  2019     1482  145  48.7         1.0        False           False
#
#    model_Edge  model_Escort  model_Fiesta  ...  model_Streetka  \
# 0       False         False          True  ...           False
# ...
